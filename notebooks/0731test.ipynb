# %%
import sys
import numpy as np

sys.path.append('../')

import mandala
from mandala import Variable
from mandala.autodiff import functions as F

# %%
x = Variable(np.ones((3, 10, 10), dtype=np.float32))

# %%
h = F.log((2 * x) ** 3 + x - 1 * x / x)

# %%
y = F.relu(h).reshape(10, 3, 10)

# %%
y.backward(gy=y.data)

# %%
x.grad.data
# Out:
# array([[[6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255]],
#
#        [[6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255]],
#
#        [[6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255],
#         [6.498255, 6.498255, 6.498255, 6.498255, 6.498255, 6.498255,
#          6.498255, 6.498255, 6.498255, 6.498255]]], dtype=float32)

# %%
y.backward()

# %%
x.grad.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9c5820e808d7> in <module>()
# ----> 1 x.grad.data
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      34     def apply_func(self):
#      35         expanded_nodes = [node.data for node in self.input_nodes]
# ---> 36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#      38     def _increment_ref_count(self):
#
# ~/mandala/mandala/autodiff/functions/reshape.py in reshape_backward(x_shape, gy)
#       8
#       9 def reshape_backward(x_shape, gy):
# ---> 10     return gy.reshape(x_shape)
#      11
#      12
#
# AttributeError: 'float' object has no attribute 'reshape'

# %%
y = x.reshape(3, 4)

# %%
y.backward(y.data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-19c8467531a6> in <module>()
# ----> 1 y.backward(y.data)
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      34     def apply_func(self):
#      35         expanded_nodes = [node.data for node in self.input_nodes]
# ---> 36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#      38     def _increment_ref_count(self):
#
# ~/mandala/mandala/autodiff/functions/reshape.py in reshape_forward(x, shape)
#       4
#       5 def reshape_forward(x, shape):
# ----> 6     return x.reshape(shape)
#       7
#       8
#
# ValueError: cannot reshape array of size 300 into shape (3,4)

# %%
x.grad.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9c5820e808d7> in <module>()
# ----> 1 x.grad.data
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in <listcomp>(.0)
#      33
#      34     def apply_func(self):
# ---> 35         expanded_nodes = [node.data for node in self.input_nodes]
#      36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#
# ~/mandala/mandala/nodecore.py in data(self)
#      56     def data(self):
#      57         if self._data is None:
# ---> 58             data = self.apply_func()
#      59             self._decrement_ref_count()
#      60             if self._reference_count > 0 or self.retain_data:
#
# ~/mandala/mandala/nodecore.py in apply_func(self)
#      34     def apply_func(self):
#      35         expanded_nodes = [node.data for node in self.input_nodes]
# ---> 36         return self.func(*expanded_nodes, **self.kwargs)
#      37
#      38     def _increment_ref_count(self):
#
# ~/mandala/mandala/autodiff/functions/reshape.py in reshape_backward(x_shape, gy)
#       8
#       9 def reshape_backward(x_shape, gy):
# ---> 10     return gy.reshape(x_shape)
#      11
#      12
#
# AttributeError: 'float' object has no attribute 'reshape'
